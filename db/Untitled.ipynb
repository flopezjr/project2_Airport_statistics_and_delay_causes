# %%
import pandas as pd
import requests
import os
import json

# %%
raw_airport_data = pd.read_csv("raw_airline_delay_causes_2013_2018.csv")

# %%
raw_airport_data.head()
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2014       4      AA  American Airlines Inc.     MFE
# 1  2014       4      AA  American Airlines Inc.     ELP
# 2  2014       4      AA  American Airlines Inc.     TPA
# 3  2014       4      AA  American Airlines Inc.     SAT
# 4  2014       4      AA  American Airlines Inc.     MCI
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Mission/McAllen/Edinburg, TX: McAllen Miller I...        146.0       34.0
# 1                 El Paso, TX: El Paso International        236.0       45.0
# 2                     Tampa, FL: Tampa International        476.0       93.0
# 3         San Antonio, TX: San Antonio International        438.0      106.0
# 4         Kansas City, MO: Kansas City International        222.0       41.0
#
#    carrier_ct   weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0       15.17         0.59  ...          0.0             12.50            0.0
# ...

# %%
#Rename columns: year, month and date
rename_airport_data = raw_airport_data.rename(columns={
    "Unnamed: 0": "uid",
    "year": "flight_year",
    " month": "flight_month",
    "airport": "locationID",
    })

# %%
rename_airport_data
# Out:
#        flight_year  flight_month carrier            carrier_name locationID  \
# 0             2014             4      AA  American Airlines Inc.        MFE
# 1             2014             4      AA  American Airlines Inc.        ELP
# 2             2014             4      AA  American Airlines Inc.        TPA
# 3             2014             4      AA  American Airlines Inc.        SAT
# 4             2014             4      AA  American Airlines Inc.        MCI
# ...            ...           ...     ...                     ...        ...
# 88558         2018            12      YX        Republic Airline        TLH
# 88559         2018            12      YX        Republic Airline        TUL
# 88560         2018            12      YX        Republic Airline        TYS
# 88561         2018            12      YX        Republic Airline        VPS
# 88562         2018            12      YX        Republic Airline        XNA
#
# ...

# %%
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ABQ") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ABE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ABI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ABR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ABY") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ACK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ACT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ACV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ACY") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ADK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ADQ") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "AEX") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "AGS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "AKN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ALB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ALO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "AMA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ANC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "APN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ART") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ASE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ATW") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "AUS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "AVL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "AVP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "AZA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "AZO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BDL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BET") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BFF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BFL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BGM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BGR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BHM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BIL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BIS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BJI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BKG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BLI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BLV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BMI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BNA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BOI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BOS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BPT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BQK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BQN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BRD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BRO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BRW") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BTM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BTR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BTV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BUF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BUR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BWI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "BZN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CAE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CAK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CDC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CDV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CEC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CGI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CHA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CHO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CHS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CIC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CID") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CIU") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CKB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CLD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CLE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CLL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CMH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CMI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ABI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CMX") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CNY") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "COD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "COS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "COU") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CPR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CRP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CRW") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CSG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CVG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CWA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "CYS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DAB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DAL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DAY") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DBQ") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DCA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DHN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DIK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DLG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DLH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DRO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DRT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DSM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DTW") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "DVL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "EAR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "EAU") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ECP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "EFD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "EGE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "EKO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ELM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ELP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ENV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ERI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ESC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "EUG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "EVV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "EWN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FAI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "EYW") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FAR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FAT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FAY") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FCA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FLG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FLL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FLO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FNL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FNT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FOE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FSD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FSM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "FWA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GCC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GCK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GEG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GFK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GGG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GJT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GNV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GPT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GRB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GRI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GRK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GRR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GSO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GSP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GST") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GTF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GTR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GUC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "GUM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HDN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HGR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HHH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HIB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HLN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HNL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HOB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HPN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HOU") ].index
rename_airport_data.drop(indexNames , inplace=True)

                         
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HRL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HSV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HTS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HVN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HYA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "HYS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "IAD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ICT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "IDA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "IFP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ILG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ILM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "IMT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "IND") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "INL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "IPL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ISN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ISP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ITH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ITO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "IYK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "JAC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "JAX") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "JLN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "JMS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "JNU") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "KOA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "KTN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LAN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LAR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LGA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LAW") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LBB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LBE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LBF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LBL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LCH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LCK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LEX") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LFT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LGB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LIH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SAT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LIT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LMT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LNK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LRD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LSE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LWB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LWS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "LYH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MAF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MBS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MCI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MCN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PHL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MDT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MDW") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MEI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MEM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MFE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MFR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MGM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MHK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MHT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MKE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MKG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MLB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MLI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MLU") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MMH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MOB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MOD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MOT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MQT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MRY") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MSN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MSO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MSP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MSY") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MTJ") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MVY") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "MYR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OAJ") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OAK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OGD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OGG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OGS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OKC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OMA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OME") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ONT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ORF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ORH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OTH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OTZ") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "OWB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PAH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PBG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PBI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PGD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PGV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PDX") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PGD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PGV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PHF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PIA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PIB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PIE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PIH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PIT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PLN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PNS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PPG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PRC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PSC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PSE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PSG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PSM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PSP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PUB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PVD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PVU") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "PWM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RAP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RDD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RDM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RDU") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RFD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RHI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RIC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RKS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RNO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ABE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ROA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ROC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "ROW") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RST") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "RSW") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SAF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SAN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SAT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SAV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SBA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SBN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SBP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SBP") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SCC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SCE") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SCK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SDF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SGF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SFB") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SGU") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SHD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SHV") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SIT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SJC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SJT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SJU") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SLC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SLN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SMF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SMX") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SNA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SPI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SPN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SPS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SRQ") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "STC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "STL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "STS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "STT") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "STX") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SUN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SUX") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SWF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SWO") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "SYR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TKI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TLH") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TOL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TPA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TRI") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TTN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TUL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TUS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TVC") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TWF") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TXK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TYR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TYR") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "TYS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "UIN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "USA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "UST") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "VEL") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "VLD") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "VPS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "WRG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "WYS") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "XNA") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "YAK") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "YNG") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "YUM") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "JAN") ].index
rename_airport_data.drop(indexNames , inplace=True)
indexNames = rename_airport_data[ (rename_airport_data['locationID'] == "IAG") ].index
rename_airport_data.drop(indexNames , inplace=True)

# %%
rename_airport_data
# Out:
#        flight_year  flight_month carrier            carrier_name locationID  \
# 9             2014             4      AA  American Airlines Inc.        CLT
# 37            2014             4      AS    Alaska Airlines Inc.        SEA
# 38            2014             4      AS    Alaska Airlines Inc.        LAX
# 39            2014             4      AS    Alaska Airlines Inc.        EWR
# 41            2014             4      AS    Alaska Airlines Inc.        MCO
# ...            ...           ...     ...                     ...        ...
# 88516         2018            12      YX        Republic Airline        IAH
# 88520         2018            12      YX        Republic Airline        JFK
# 88528         2018            12      YX        Republic Airline        MCO
# 88531         2018            12      YX        Republic Airline        MIA
# 88539         2018            12      YX        Republic Airline        ORD
#
# ...

# %%
airport_data = rename_airport_data.filter([
        'flight_year',
        'flight_month',
        'carrier',
        'carrier_name',
        'locationID',
        'airport_name',
        'arr_flights',
        'arr_del15',
        'carrier_ct',
        'weather_ct',
        'security_ct',
        'late_aircraft_ct',
        'arr_cancelled',
        'arr_diverted',
        'arr_delay',
        'carrier_delay',
        'weather_delay',
        'nas_delay',
        'security_delay',
        'late_aircraft_delay',
    ])

# %%
airport_data.to_csv("clean_topairport_delays_2013_2018.csv")
